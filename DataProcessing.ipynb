# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./data/train.csv')
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 1100 non-null   int64
#  1   Age                       1100 non-null   int64
#  2   BusinessTravel            1100 non-null   object
#  3   Department                1100 non-null   object
#  4   DistanceFromHome          1100 non-null   int64
#  5   Education                 1100 non-null   int64
#  6   EducationField            1100 non-null   object
#  7   EmployeeNumber            1100 non-null   int64
#  8   EnvironmentSatisfaction   1100 non-null   int64
#  9   Gender                    1100 non-null   object
#  10  JobInvolvement            1100 non-null   int64
#  11  JobLevel                  1100 non-null   int64
#  12  JobRole                   1100 non-null   object
#  13  JobSatisfaction           1100 non-null   int64
# ...

# %%
data.head()
# data.EducationField.value_counts()
# data.drop_duplicates(inplace=True)
# data.dropna(inplace=True)
# data.info()
# Out:
#    Attrition  Age     BusinessTravel              Department  \
# 0          0   37      Travel_Rarely  Research & Development
# 1          0   54  Travel_Frequently  Research & Development
# 2          1   34  Travel_Frequently  Research & Development
# 3          0   39      Travel_Rarely  Research & Development
# 4          1   28  Travel_Frequently  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          4  Life Sciences              77
# 1                 1          4  Life Sciences            1245
# 2                 7          3  Life Sciences             147
# 3                 1          1  Life Sciences            1026
# 4                 1          3        Medical            1111
#
#    EnvironmentSatisfaction  Gender  ...  RelationshipSatisfaction  \
# 0                        1    Male  ...                         3
# 1                        4  Female  ...                         1
# ...

# %%
data.BusinessTravel.value_counts()
def dataMapping(data):
    if data == 'Yes':
        return 1
    else:
        return 0
x_dummies = pd.get_dummies(data,columns=['BusinessTravel'])
x_dummies['OverTime']=x_dummies.OverTime.map(dataMapping)
x_dummies.head()
# Out:
#    Attrition  Age              Department  DistanceFromHome  Education  \
# 0          0   37  Research & Development                 1          4
# 1          0   54  Research & Development                 1          4
# 2          1   34  Research & Development                 7          3
# 3          0   39  Research & Development                 1          1
# 4          1   28  Research & Development                 1          3
#
#   EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0  Life Sciences              77                        1    Male
# 1  Life Sciences            1245                        4  Female
# 2  Life Sciences             147                        1    Male
# 3  Life Sciences            1026                        4  Female
# 4        Medical            1111                        1    Male
#
#    JobInvolvement  ...  TotalWorkingYears TrainingTimesLastYear  \
# 0               2  ...                  7                     2
# ...

# %%
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 res
#
# NameError: name 'res' is not defined

# %%
# data.iloc[:,1:5].boxplot() 
# data[['Attrition','MonthlyIncome']].plot()
sns.kdeplot(data = data[data['Attrition']==1], x='MonthlyIncome',label = 'Attr')
sns.kdeplot(data = data[data['Attrition']==0], x='MonthlyIncome',label = 'not')
plt.grid(True)
plt.legend(loc='best')
